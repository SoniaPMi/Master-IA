# %% [markdown]
# # Entrenamiento de Autoencoders con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Lambda
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# # USO: Reducir la Dimensionalidad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x_shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ## Carga y procesamiento de los datos

# %%
# Carga
(X_train, y_train), (X_test, _) = tf.keras.datasets.mnist.load_data()
print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Entradas Test:', X_test.shape)

# Normalización
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

print('Cambio de dimensiones para ajustar a la entrada de un Perceptrón:')
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Entradas Test:', X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Entradas Test: (10000, 28, 28)
# Cambio de dimensiones para ajustar a la entrada de un Perceptrón:
#  -Entradas Entrenamiento: (60000, 784)
#  -Entradas Test: (10000, 784)

# %% [markdown]
# ## Autoencoder profundo
# ### Creación del autoencoder
# Vamos a crear un autoencoder que codifique y decodifique la entrada de 728 píxeles en la siguiente secuencia de dimensiones:
#
# 784 → 128 → 64 → 32 → 64 → 128 → 784

# %%
x_shape
# Out:
# (60000, 28, 28)

# %%
# Tamaño de nuestra representación codificada
encoding_dim = 32  # Factor de compresión = 24.5 (dado que la entrada es de tamaño 784)

# Definimos las capas para la entrada, el encoder y el decoder:
# Capa de entrada
input_img = Input(shape=(784,), name = 'Input')

# Capas del encoder
encoder1 = Dense(128, activation='relu', name='Encoder1')
encoder2 = Dense(64, activation='relu', name='Encoder2')
encoder3 = Dense(encoding_dim, activation='relu', name='Encoder3')

# Capas del decoder
decoder1 = Dense(64, activation='relu', name='Decorder1')
decoder2 = Dense(128, activation='relu', name='Decoder2')
decoder3 = Dense(784, activation='sigmoid', name='Decoder3')

#       Autoencoder
# --------------------------
# "encoded" es la representación codificada de la entrada (cada vez más comprimida)
encoded1 = encoder1(input_img)
encoded2 = encoder2(encoded1)
encoded3 = encoder3(encoded2)

# "decoded" es la reconstrución de la entrada a partir de la entrada codificada
decoded1 = decoder1(encoded3)
decoded2 = decoder2(decoded1)
decoded3 = decoder3(decoded2)

# Modelo que reconstruye una entrada
autoencoder = tf.keras.Model(input_img, decoded3)

# Visualizar arquitectura y dimensiones
print(f"{'*'*65}\n\t\t\tAutoencoder\n{'*'*65}")
autoencoder.summary()
# Out:
# *****************************************************************
# 			Autoencoder
# *****************************************************************
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 784)]             0
#
#  Encoder1 (Dense)            (None, 128)               100480
#
#  Encoder2 (Dense)            (None, 64)                8256
#
#  Encoder3 (Dense)            (None, 32)                2080
#
#  Decorder1 (Dense)           (None, 64)                2112
#
#  Decoder2 (Dense)            (None, 128)               8320
#
#  Decoder3 (Dense)            (None, 784)               101136
#
# =================================================================
# Total params: 222,384
# Trainable params: 222,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
#tengo la misma entrada que salida, ya que quiero ver el error o reducir el ruido
hist= autoencoder.fit(X_test, 
                      X_test,
                      epochs=50,
                      batch_size=256,
                      shuffle=True,
                      validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 40/40 [==============================] - 3s 15ms/step - loss: 0.4043 - val_loss: 0.2714
# Epoch 2/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.2607 - val_loss: 0.2486
# Epoch 3/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.2356 - val_loss: 0.2178
# Epoch 4/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.2019 - val_loss: 0.1859
# Epoch 5/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1786 - val_loss: 0.1725
# Epoch 6/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1676 - val_loss: 0.1630
# Epoch 7/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1589 - val_loss: 0.1550
# Epoch 8/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1520 - val_loss: 0.1492
# Epoch 9/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1471 - val_loss: 0.1447
# Epoch 10/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1425 - val_loss: 0.1419
# Epoch 11/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1385 - val_loss: 0.1363
# Epoch 12/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1346 - val_loss: 0.1337
# Epoch 13/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1322 - val_loss: 0.1301
# Epoch 14/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1296 - val_loss: 0.1287
# Epoch 15/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1277 - val_loss: 0.1275
# Epoch 16/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1261 - val_loss: 0.1260
# Epoch 17/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1243 - val_loss: 0.1235
# Epoch 18/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1227 - val_loss: 0.1221
# Epoch 19/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1209 - val_loss: 0.1203
# Epoch 20/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1195 - val_loss: 0.1194
# Epoch 21/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1182 - val_loss: 0.1176
# Epoch 22/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1170 - val_loss: 0.1183
# Epoch 23/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1159 - val_loss: 0.1159
# Epoch 24/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1147 - val_loss: 0.1145
# Epoch 25/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1135 - val_loss: 0.1143
# Epoch 26/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1127 - val_loss: 0.1122
# Epoch 27/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1116 - val_loss: 0.1133
# Epoch 28/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1113 - val_loss: 0.1112
# Epoch 29/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1103 - val_loss: 0.1105
# Epoch 30/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.1096 - val_loss: 0.1093
# Epoch 31/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1089 - val_loss: 0.1086
# Epoch 32/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1081 - val_loss: 0.1082
# Epoch 33/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1077 - val_loss: 0.1077
# Epoch 34/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1073 - val_loss: 0.1080
# Epoch 35/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1068 - val_loss: 0.1072
# Epoch 36/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1062 - val_loss: 0.1058
# Epoch 37/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1055 - val_loss: 0.1058
# Epoch 38/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1052 - val_loss: 0.1059
# Epoch 39/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1049 - val_loss: 0.1049
# Epoch 40/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1043 - val_loss: 0.1043
# Epoch 41/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1037 - val_loss: 0.1039
# Epoch 42/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1032 - val_loss: 0.1033
# Epoch 43/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1028 - val_loss: 0.1025
# Epoch 44/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1023 - val_loss: 0.1034
# Epoch 45/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1020 - val_loss: 0.1024
# Epoch 46/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1016 - val_loss: 0.1013
# Epoch 47/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1012 - val_loss: 0.1017
# Epoch 48/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1008 - val_loss: 0.1007
# Epoch 49/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.1002 - val_loss: 0.1003
# Epoch 50/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0999 - val_loss: 0.0999

# %% [markdown]
# ### Evaluación y visualización

# %%
plt.figure()
plt.xlabel('Épocas')
plt.ylabel('Error')
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['Entrenamiento', 'Validación']);

# %%
# Vamos a crear ahora por un lado un modelo para el encoder y otro para el decoder
#          Encoder
# ------------------------
encoder = tf.keras.Model(input_img, encoded3)
decoder = tf.keras.Model(encoded3, decoded3)

# Visualizar arquitectura y dimensiones
print(f"\n{'*'*65}\n\t\t\tEncoder\n{'*'*65}")
encoder.summary()

# Codificamos y decodificamos algunos dígitos de ejemplo (datos de test)
# -----------------------
encoded_imgs = encoder.predict(X_test)

decoded_imgs = autoencoder.predict(X_test)
 
n_images = 10 
plt.figure(figsize=(30, 4))
for i in range(n_images):
    # Entrada (original)
    plt.subplot(3, n_images, i + 1)
    plt.imshow(X_test[i].reshape(28, 28), cmap='gray')
    plt.title('Entrada')
    plt.axis('off')

    # Codificación
    plt.subplot(3, n_images, i + 1 + n_images)
    plt.imshow(encoded_imgs[i].reshape(1, encoding_dim), cmap='gray') #encoding dim=32 dado que la capa de el media tiene "filtro"=32
    plt.axis('off')
    plt.title('Entrada codificada')
    
    # Reconstrucción
    plt.subplot(3, n_images, i + 1 + n_images + n_images)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    plt.title('Reconstrucción')
# Out:
# *****************************************************************
# 			Encoder
# *****************************************************************
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 784)]             0
#
#  Encoder1 (Dense)            (None, 128)               100480
#
#  Encoder2 (Dense)            (None, 64)                8256
#
#  Encoder3 (Dense)            (None, 32)                2080
#
# =================================================================
# Total params: 110,816
# Trainable params: 110,816
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Aplicación: Eliminación de ruido
# Para obtener un modelo capaz de eliminar ruido de las imágenes de dígitos vamos a entrenar un autoencoder que mapee imágenes de dígitos con ruido (entrada) a imágenes de dígitos "limpias".

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Añadimos ruido gaussiano (distribución normal) a las imágenes.
noise_factor = 0.5
X_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape) 
X_test_noisy = X_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape) 

# Aseguramos que todos los pixeles queden en el rango [0, 1]
X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# Dibujamos las imágenes con ruido
n_images = 10
plt.figure(figsize=(30, 3))
for i in range(n_images):
    plt.subplot(1, n_images, i+1)
    plt.imshow(X_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.axis('off')

# %%
X_train_noisy.shape[1]
# Out:
# 784

# %% [markdown]
# ### Creación del modelo y entrenamiento

# %%
# Creación del modelo
encoding_dim = 32
autoencoder = tf.keras.models.Sequential()

autoencoder.add(Dense(units=128, activation='relu', input_shape=(X_train_noisy.shape[1],)))
autoencoder.add(Dense(units=64, activation='relu',))
autoencoder.add(Dense(units=encoding_dim, activation='relu',))
autoencoder.add(Dense(units=64, activation='relu',))
autoencoder.add(Dense(units=128, activation='relu',))
autoencoder.add(Dense(units=X_train_noisy.shape[1], activation='sigmoid',))
#       .
#       .

# Entrenamiento
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
hist= autoencoder.fit(X_train_noisy, 
                      X_train,
                      epochs=50,
                      batch_size=256,
                      shuffle=True,
                      validation_data=(X_test_noisy, X_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2646 - val_loss: 0.2043
# Epoch 2/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1839 - val_loss: 0.1720
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1672 - val_loss: 0.1603
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1564 - val_loss: 0.1511
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1487 - val_loss: 0.1452
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1442 - val_loss: 0.1418
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1413 - val_loss: 0.1391
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1384 - val_loss: 0.1366
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.1356 - val_loss: 0.1338
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1333 - val_loss: 0.1319
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1316 - val_loss: 0.1303
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1300 - val_loss: 0.1293
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1289 - val_loss: 0.1289
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1278 - val_loss: 0.1273
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1267 - val_loss: 0.1264
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1260 - val_loss: 0.1261
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1253 - val_loss: 0.1251
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1246 - val_loss: 0.1244
# Epoch 19/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1238 - val_loss: 0.1239
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1231 - val_loss: 0.1230
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1227 - val_loss: 0.1231
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1223 - val_loss: 0.1226
# Epoch 23/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1217 - val_loss: 0.1222
# Epoch 24/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1213 - val_loss: 0.1217
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1210 - val_loss: 0.1217
# Epoch 26/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1206 - val_loss: 0.1211
# Epoch 27/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1201 - val_loss: 0.1210
# Epoch 28/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1198 - val_loss: 0.1203
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1194 - val_loss: 0.1203
# Epoch 30/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1192 - val_loss: 0.1203
# Epoch 31/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1189 - val_loss: 0.1199
# Epoch 32/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1186 - val_loss: 0.1198
# Epoch 33/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1184 - val_loss: 0.1200
# Epoch 34/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1180 - val_loss: 0.1193
# Epoch 35/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1177 - val_loss: 0.1188
# Epoch 36/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1175 - val_loss: 0.1187
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1171 - val_loss: 0.1184
# Epoch 38/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1169 - val_loss: 0.1182
# Epoch 39/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1167 - val_loss: 0.1183
# Epoch 40/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1165 - val_loss: 0.1181
# Epoch 41/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1163 - val_loss: 0.1182
# Epoch 42/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1161 - val_loss: 0.1184
# Epoch 43/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1158 - val_loss: 0.1175
# Epoch 44/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1157 - val_loss: 0.1174
# Epoch 45/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1154 - val_loss: 0.1174
# Epoch 46/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1154 - val_loss: 0.1174
# Epoch 47/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1152 - val_loss: 0.1171
# Epoch 48/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1150 - val_loss: 0.1174
# Epoch 49/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1148 - val_loss: 0.1167
# Epoch 50/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1147 - val_loss: 0.1167

# %% [markdown]
# ### Evaluación y visualización

# %%
plt.figure()
plt.xlabel('Épocas')
plt.ylabel('Error')
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['Entrenamiento', 'Validación'])

predictions = autoencoder.predict(X_test)
n_images = 10 
plt.figure(figsize=(30, 8))
for i in range(n_images):
    # Entrada (original)
    plt.subplot(3, n_images, i + 1)
    plt.imshow(X_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title('Entrada')
    plt.axis('off')
    
    # Reconstrucción
    plt.subplot(3, n_images, i + 1 + n_images)
    plt.imshow(predictions[i].reshape(28, 28), cmap='gray')
    plt.axis('off')
    plt.title('Reconstrucción')

# %% [markdown]
# ## Autoencoder Variacional
# ### Creación del Encoder

# %%
class Encoder(tf.keras.Model):
  def __init__(self):
    super(Encoder, self).__init__()

    # Capas del encoder
    self.encoder1 = Dense(128, activation='relu', name='Encoder1')
    self.encoder2 = Dense(64, activation='relu', name='Encoder2')
    self.encoder3 = Dense(32, activation='relu', name='Encoder3')

  def call(self, inputs, training=None, mask=None):
    x = self.encoder1(inputs)
    x = self.encoder2(x)
    y = self.encoder3(x)
    #
    return y

# %% [markdown]
# ### Creación de la capa que representa la distribución normal

# %%
class NormalDistribution(tf.keras.Model):
  def __init__(self):
    super(NormalDistribution, self).__init__()
    
    # Capas
    self.z_mean = Dense(2, name='z_mean', activation='linear')
    self.z_log_var = Dense(2, name='z_log_var', activation='linear')


  def call(self, inputs, training=None, mask=None):
    z_mean = self.z_mean(inputs)
    z_log_var = self.z_log_var(inputs)
   
    return z_mean, z_log_var

# %% [markdown]
# ### Creación de la capa de muestreo

# %%
class Reparametrize(tf.keras.layers.Layer):
  """
  Usa (z_mu, z_log_var) para muestrear z (el vector que 
  representa el dígito codificado)
  """
  def call(self, inputs):
    z_mu, z_log_var = inputs
    
    # Extraemos dimensiones (del batch y del espacio codificado)
    #       .
    #       .
    #       .
    
    # Muestreamos de una distribucion normal ϵ: con dimensiones (batch, dim_spacio_codificado)
    #       .
    #       .
    #       .
    
    # Transformamos log(σ^2) en σ 
    #       .
    #       .
    #       .

    # Truco de re-parametrización
    #       .
    #       .
    #       .
    
    return reparametrization

# %% [markdown]
# ### Creación del Decoder

# %%
class Decoder(tf.keras.Model):
  def __init__(self):
    super(Decoder, self).__init__()

    # Capas del decoder
    #       .
    #       .
    #       .

  def call(self, inputs,  training=None, mask=None):
    #       .
    #       .
    #       .
    return y

# %% [markdown]
# ### Creación de la función de coste

# %%
class LossVAE(tf.keras.layers.Layer):
  """
  Función de error custom: suma del término de reconstrucción y 
  el término de regularización KL divergence
  """
  def call(self, inputs):
    y_true, y_pred, z_mean, z_log_var = inputs
    
    # Error de reconstrucción (usa categorical_crossentroy)
    #       .
    #       .
    #       .
    
    # Divergencia KL
    #       .
    #       .
    #       .
  
    return reconstruction_loss, kl_loss

# %% [markdown]
# ### Creación del Autoencoder Variacional

# %%
class VAE(tf.keras.Model):
    def __init__(self):
      super(VAE, self).__init__()
      # Capas del VAE
      #       .
      #       .
      #       .

    def call(self, inputs,  training=None, mask=None):
      #       .
      #       .
      #       .
      return (z_mean, z_log_var, z), decoded

    def train_step(self, data):
      with tf.GradientTape() as tape:
        # Propagación hacia delante
        #       .
        #       .
        #       .
        total_loss = (784 * reconstruction_loss) + (2 * kl_loss)
      
      # Retro-propagación
      grads = tape.gradient(total_loss, self.trainable_weights)
      
      # Actualización de los pesos
      self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
      
      return {"reconstruction_loss": reconstruction_loss,
              "kl_loss": kl_loss,
              "total_loss": total_loss}

# %% [markdown]
# ### Entrenamiento del Autoencoder Variacional

# %%
vae = VAE()
vae.compile(optimizer=tf.keras.optimizers.Adam())
vae.fit(X_train, epochs=30, batch_size=128)

# %% [markdown]
# ### Muestra de Dígitos Generados con el Autoencoder Varacional

# %%
def plot_latent(model, fig_size=15, scale=3.):
    n = 30
    digit_size = 28
    figure = np.zeros((digit_size * n, digit_size * n))
    # Creamos un grid 2D linealmente espaciado correspondiente a
    # los dígitos en el espacio codificado
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            # Para cada coordenada 2D del espacio codificado, 
            # usamos el decoder para reconstruir/generar una imagen nueva.
            x_decoded = model.decoder(z_sample).numpy()
            digit = x_decoded.reshape(digit_size, digit_size)
            figure[i * digit_size : (i + 1) * digit_size,
                   j * digit_size : (j + 1) * digit_size] = digit

    plt.figure(figsize=(fig_size, fig_size))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="gray")
    plt.show()


def plot_label_clusters(model, data, labels, fig_size=15, scale=3.):
    # Dibujamos un plot 2D the los dígitos y sus clases en el espacio codificado
    encoded = model.encoder(data)
    z_mean, _ = model.normal_distribution(encoded)
    plt.figure(figsize=(fig_size, fig_size))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.xlim((-scale, scale))
    plt.ylim((-scale, scale)) 
    plt.show()

# %%
plot_latent(vae)

# %%
plot_label_clusters(vae, X_train, y_train)
